# %%
import numpy as np
from scipy.stats import linregress
import csv

# %%
ls
# Out:
# 1090328576_temp.csv          Del_RA-W2.png
# 1090328576_temp_full.csv     Delta_Dec-Extreme.png
# DelDec_DelRA_Plotcode.ipynb  Delta_Dec.png
# Del_Dec-freq.png             Delta_RA-Extreme.png
# Del_Dec-W2.png               Delta_RA.png
# Del_RA-freq.png              Ionospheric shift testing.ipynb

# %%
reader=csv.reader(open("1090328576_temp.csv","rb"),delimiter=',')

# %%
x=list(reader)

# %%
print x
# Out:
# [['delRA', 'arcminutes', 'Resid', '', 'delDec', ''], ['-0.00248281122804883', '-0.14896867368293', '0.170192039557264', '', '-0.00500155938341607', '-0.300093563004964'], ['-0.00841274522491631', '-0.504764713494978', '-0.185604000254784', '', '-0.0116207139458488', '-0.697242836750931'], ['0.00118175883426375', '0.0709055300558248', '0.390066243296019', '', '-0.0105418119016036', '-0.632508714096218'], ['-0.00423551021606272', '-0.254130612963763', '0.0650301002764309', '', '-0.0124337759465192', '-0.746026556791151'], ['-0.00767864691931664', '-0.460718815158998', '-0.141558101918804', '', '-0.0128426204335845', '-0.770557226015072'], ['-0.0052428908403499', '-0.314573450420994', '0.00458726281920003', '', '-0.011544802791601', '-0.692688167496058'], ['-0.00042987219802626', '-0.0257923318815756', '0.293368381358619', '', '-0.0165770014653326', '-0.994620087919955'], ['0.0055496476834378', '0.332978861006268', '0.652139574246462', '', '-0.0106106906179519', '-0.636641437077117'], [
# ...

# %%
csv = np.genfromtxt ('1090328576_temp.csv', delimiter=",")

# %%
DelRA_arcmin = csv[:,1]

# %%
print DelRA_arcmin
# Out:
# [        nan -0.14896867 -0.50476471  0.07090553 -0.25413061 -0.46071882
#  -0.31457345 -0.02579233  0.33297886 -0.73825371 -0.81463458 -0.63120302
#   2.00607678  1.78089003 -0.32374798 -0.15983238 -1.75113243  0.64236244
#   2.3290728   2.32735267 -0.58605985 -0.89030949 -0.41795186 -1.09665292
#  -0.39167877  0.33122424 -0.34039666  0.86651255  0.06864525  0.13891498
#  -0.35968447 -1.27429954 -0.33579048 -0.52081669  0.5008388          nan
#  -0.31916071 -0.02781231]

# %%
DelDec_arcmin = csv[:,5]

# %%
print DelDec_arcmin
# Out:
# [        nan -0.30009356 -0.69724284 -0.63250871 -0.74602656 -0.77055723
#  -0.69268817 -0.99462009 -0.63664144 -1.07661816 -1.21918341 -1.13469285
#  -0.05057891 -0.0696064  -1.17892363 -1.05808163 -1.23169096 -0.70029626
#  -0.10904744 -0.0661041  -0.56817606 -0.4336195  -0.7387505  -0.48746806
#  -0.43402859 -0.51842186 -0.60417277 -0.56082747 -0.59996929 -0.66064222
#  -0.37585288 -0.38633422 -0.13312226 -0.83609277 -0.56386327         nan
#  -0.61834074         nan]

# %%
average=np.nanmean(DelRA_arcmin)
print average
# Out:
# -0.035905319626

# %%
DelRA_degrees = csv[:,0]
print DelRA_degrees
# Out:
# [        nan -0.00248281 -0.00841275  0.00118176 -0.00423551 -0.00767865
#  -0.00524289 -0.00042987  0.00554965 -0.01230423 -0.01357724 -0.01052005
#   0.03343461  0.0296815  -0.0053958  -0.00266387 -0.02918554  0.01070604
#   0.03881788  0.03878921 -0.00976766 -0.01483849 -0.00696586 -0.01827755
#  -0.00652798  0.0055204  -0.00567328  0.01444188  0.00114409  0.00231525
#  -0.00599474 -0.02123833 -0.00559651 -0.00868028  0.00834731         nan
#  -0.00531935         nan]

# %%
DelRA_average=np.nanmean(DelRA_degrees)
print DelRA_average
# Out:
# -0.000602275808646

# %%
DelDec_degrees = csv[:,4]

# %%
DelDec_average=np.nanmean(DelDec_degrees)
print DelDec_average
# Out:
# -0.0104213737173

# %%
print DelDec_average * 3600
# Out:
# -37.5169453822

# %%
print DelRA_average * 3600
# Out:
# -2.16819291113
